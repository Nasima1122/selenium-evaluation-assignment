# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/  ")

# %%
#entering the designation
designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Analyst')

# %%
#entering the location
location=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_features__wJid6"]')
for i in title_tags:
    title=i.text
    job_title.append(title)

# %%
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)

# %%
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)

# %%
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_Name':company_name,'Experience':experience_required})
df
# Out:
#                   Title        Location  \
# 0            6 days ago   Bangalore\n+9
# 1            4 days ago   Bangalore\n+6
# 2           2 weeks ago   Bangalore\n+9
# 3           2 weeks ago  Bangalore\n+12
# 4            1 week ago   Bangalore\n+6
# 5        Hot\n1 day ago   Bangalore\n+9
# 6          2 months ago       Bangalore
# 7          2 months ago   Bangalore\n+3
# 8       Hot\n0 days ago   Bangalore\n+9
# 9           3 weeks ago       Bangalore
# 10  Premium\n6 days ago   Bangalore\n+2
# 11           5 days ago   Bangalore\n+9
# 12           4 days ago   Bangalore\n+6
# 13          2 weeks ago   Bangalore\n+4
# 14           1 week ago       Bangalore
# 15         2 months ago       Bangalore
# 16         2 months ago       Bangalore
# 17           1 week ago   Bangalore\n+9
# 18         2 months ago       Bangalore
# 19         2 months ago       Bangalore
#
#                               Company_Name    Experience
# 0                 sahast sales corporation  12 to 22 Yrs
# 1                            techno endura     0 to 1 Yr
# 2                 sahast sales corporation  12 to 22 Yrs
# 3                      radhika enterprises    0 to 4 Yrs
# 4                            techno endura     0 to 1 Yr
# 5                  v-tech data outsourcing     0 to 1 Yr
# 6            ara resources private limited    4 to 9 Yrs
# 7        diraa hr services hiring for mncs     0 to 1 Yr
# 8                  pick bright hr solution    0 to 2 Yrs
# 9      uprighthc solutions private limited  10 to 20 Yrs
# 10                     ltimindtree limited    5 to 9 Yrs
# 11                 v-tech data outsourcing     0 to 1 Yr
# 12                           techno endura     0 to 1 Yr
# 13                   symphoni hr pvt. ltd.   8 to 10 Yrs
# 14                        spm hr solutions    4 to 6 Yrs
# 15  boyen haddin consulting and technol...    3 to 6 Yrs
# 16  boyen haddin consulting and technol...    3 to 6 Yrs
# 17                         aspect solution     0 to 1 Yr
# 18  boyen haddin consulting and technol...    3 to 6 Yrs
# 19  boyen haddin consulting and technol...    3 to 6 Yrs

# %%
df[:10]
# Out:
#              Title        Location                         Company_Name  \
# 0       6 days ago   Bangalore\n+9             sahast sales corporation
# 1       4 days ago   Bangalore\n+6                        techno endura
# 2      2 weeks ago   Bangalore\n+9             sahast sales corporation
# 3      2 weeks ago  Bangalore\n+12                  radhika enterprises
# 4       1 week ago   Bangalore\n+6                        techno endura
# 5   Hot\n1 day ago   Bangalore\n+9              v-tech data outsourcing
# 6     2 months ago       Bangalore        ara resources private limited
# 7     2 months ago   Bangalore\n+3    diraa hr services hiring for mncs
# 8  Hot\n0 days ago   Bangalore\n+9              pick bright hr solution
# 9      3 weeks ago       Bangalore  uprighthc solutions private limited
#
#      Experience
# 0  12 to 22 Yrs
# 1     0 to 1 Yr
# 2  12 to 22 Yrs
# 3    0 to 4 Yrs
# 4     0 to 1 Yr
# 5     0 to 1 Yr
# 6    4 to 9 Yrs
# 7     0 to 1 Yr
# 8    0 to 2 Yrs
# 9  10 to 20 Yrs
