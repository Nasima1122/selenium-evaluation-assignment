# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %%
driver= webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/apple-iphone-15-black-128-gb/p/itm6ac6485515ae4?")

# %%
rating_phone=[]
review_title=[]
review_detail=[]

# %%
start=0
end=10
for page in range(start,end):

    phone=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in phone:
        rating_phone.append(i.text)
    title=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in title:
        review_title.append(i.text)
    detail=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in detail:
        review_detail.append(i.text)

# %%
print(len(rating_phone),len(review_title),len(review_detail))
# Out:
# 130 130 130

# %%
df=pd.DataFrame({'Phone':rating_phone,'Title':review_title,'Detail':review_detail})
df
# Out:
#     Phone                  Title  \
# 0       5              Just wow!
# 1       4            Good choice
# 2       5  Mind-blowing purchase
# 3       5     Highly recommended
# 4       4        Worth the money
# ..    ...                    ...
# 125     5         Classy product
# 126     5                Awesome
# 127     5              Brilliant
# 128     4            Really Nice
# 129     5         Simply awesome
#
#                                                 Detail
# 0                 Camera Quality Is Improved Loving It
# 1                                            Very nice
# 2                                 High quality camera😍
# 3    I love this phone. The camera is amazing: its ...
# 4    Best mobile phone\nCamera quality is very nice...
# ..                                                 ...
# 125                                            Nice ❤️
# 126  Switch from OnePlus to iPhone I am stunned wit...
# 127  Totally happy!\nCamera 5\nBattery 5\nDisplay 5...
# ...

# %%
df[:100]
# Out:
#    Phone                  Title  \
# 0      5              Just wow!
# 1      4            Good choice
# 2      5  Mind-blowing purchase
# 3      5     Highly recommended
# 4      4        Worth the money
# ..   ...                    ...
# 95     5         Classy product
# 96     5                Awesome
# 97     5              Brilliant
# 98     4            Really Nice
# 99     5         Simply awesome
#
#                                                Detail
# 0                Camera Quality Is Improved Loving It
# 1                                           Very nice
# 2                                High quality camera😍
# 3   I love this phone. The camera is amazing: its ...
# 4   Best mobile phone\nCamera quality is very nice...
# ..                                                ...
# 95                                            Nice ❤️
# 96  Switch from OnePlus to iPhone I am stunned wit...
# 97  Totally happy!\nCamera 5\nBattery 5\nDisplay 5...
# ...
